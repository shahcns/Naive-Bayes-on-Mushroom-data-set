# %% [markdown]
# <h1 style='background-color:Powderblue'><center><font color='Green'>Naive Bayes Study in Mashroom Data Set</font></center></h1><br>
#
# [Click here for detailed note about Mushrooms](https://sciencing.com/characteristics-mushrooms-8308611.html#:~:text=Physical%20Characteristics,can%20be%20occupied%20by%20pores.)<br>
#
# # 1. <font color='Red'> Loading Essential library</font>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.naive_bayes import GaussianNB, BernoulliNB,MultinomialNB
import warnings

# %% [markdown]
# # 2. <font color='Red'> Loading Data Set to python</font>

# %%
df=pd.read_csv(r'C:\Users\Lenovo\OneDrive\Desktop\ICT Academy\CS10 mushrooms.csv')

# %%
df.head(10)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
# 5     e         x           y         y       t    a               f
# 6     e         b           s         w       t    a               f
# 7     e         b           y         w       t    l               f
# 8     p         x           y         w       t    p               f
# 9     e         b           s         y       t    a               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# ...

# %% [markdown]
# Here our data set is seems like contain only nominal values.
#
# ## Some Basic Preprocessing
#
# ### i. Shape of data set

# %%
print('The no of rows & coloumns are respectively',df.shape)
# Out:
# The no of rows & coloumns are respectively (8124, 23)

# %% [markdown]
# ### ii. Checking Missing Values

# %%
df.isna().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %% [markdown]
# __Interpretation__
# <p style='background-color:Red'>
# Since the whole data where categorical variables, then the statistics about the sample data is meaningless.</p><br>
# Also  there is no missing values in data set so we can proceed with further steps.<br>
#
# # 3. <font color='Red'> Feature Scaling </font>

# %%
le=LabelEncoder()
df1=df.apply(le.fit_transform)
df1.head(5)
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
df1.isna().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
df1.corr()
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %% [markdown]
# **Conclusion**<br>
# Here the correlation between the variables has not that much importance. since because the variables where categorical so it also meaning less <br>
#
# # 4. <font color='Red'> Modeling  </font>
# ## a. Splitting Data set into independent variable and Dependent variable.

# %%
X=df1.iloc[:,1:].values
y=df1.iloc[:,[0]].values
X
# Out:
# array([[5, 2, 4, ..., 2, 3, 5],
#        [5, 2, 9, ..., 3, 2, 1],
#        [0, 2, 8, ..., 3, 2, 3],
#        ...,
#        [2, 2, 4, ..., 0, 1, 2],
#        [3, 3, 4, ..., 7, 4, 2],
#        [5, 2, 4, ..., 4, 1, 2]])

# %% [markdown]
# **Note:**<br>
# Here we took the whole variables except the "Class" column because the we can see that in given above link, which was the study about the Mushroom, in that it is clear that all preticulars of Head, Stem/Stalk and root has much influence in order to determine wheather it is edible or not.
#
# ## b. Scaling the Splitted Data set.

# %%
X=StandardScaler().fit_transform(X)
X
# Out:
# array([[ 1.02971224,  0.14012794, -0.19824983, ..., -0.67019486,
#         -0.5143892 ,  2.03002809],
#        [ 1.02971224,  0.14012794,  1.76587407, ..., -0.2504706 ,
#         -1.31310821, -0.29572966],
#        [-2.08704716,  0.14012794,  1.37304929, ..., -0.2504706 ,
#         -1.31310821,  0.86714922],
#        ...,
#        [-0.8403434 ,  0.14012794, -0.19824983, ..., -1.50964337,
#         -2.11182722,  0.28570978],
#        [-0.21699152,  0.95327039, -0.19824983, ...,  1.42842641,
#          0.28432981,  0.28570978],
#        [ 1.02971224,  0.14012794, -0.19824983, ...,  0.16925365,
#         -2.11182722,  0.28570978]])

# %% [markdown]
# ## c. Further splitted the data set into Training set and Testing data.

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.3)
print('The no of rows and columns of training set of independent variables is:', X_train.shape)
# Out:
# The no of rows and columns of training set of independent variables is: (5686, 22)

# %% [markdown]
# ## d. Fitting the different flavours of NB.
# ### <font color='tomato'>I Gaussing Naive Bayes </font>

# %%
fit1=GaussianNB().fit(X_train,y_train,)
y_pred_G=fit1.predict(X_test)
y_pred_G
warnings.filterwarnings('ignore')

# %%
c1=pd.DataFrame(y_test,y_pred_G)
c1.reset_index(inplace=True)
c1.rename(columns={'index':'Actual',0:'Predicted'},inplace=True)
c1.head()
# Out:
#    Actual  Predicted
# 0       0          0
# 1       1          1
# 2       1          1
# 3       0          0
# 4       1          1

# %%
print('The Confusion Matrix of Gaussian Naive Bayes is :',confusion_matrix(y_test,y_pred_G))
# Out:
# The Confusion Matrix of Gaussian Naive Bayes is : [[1172   85]
#  [  87 1094]]

# %% [markdown]
# Here we can see that among 2438, 2266 were correctly predicted and 172 wrongly predicted.

# %%
print('The Accuracy score of Gaussian Naive Bayes is :',accuracy_score(y_test,y_pred_G))
# Out:
# The Accuracy score of Gaussian Naive Bayes is : 0.9294503691550451

# %% [markdown]
# ### <font color='tomato'>II Bernoulli Naive Bayes </font>

# %%
fit2=BernoulliNB().fit(X_train,y_train,)
y_pred_B=fit2.predict(X_test)
y_pred_B
# Out:
# array([0, 1, 1, ..., 1, 0, 0])

# %%
c2=pd.DataFrame(y_test,y_pred_B)
c2.reset_index(inplace=True)
c2.rename(columns={'index':'Actual',0:'Predicted'},inplace=True)
c2.head()
# Out:
#    Actual  Predicted
# 0       0          0
# 1       1          1
# 2       1          1
# 3       0          0
# 4       1          1

# %%
print('The Confusion Matrix of Bernoulli Naive Bayes is :',confusion_matrix(y_test,y_pred_B))
# Out:
# The Confusion Matrix of Bernoulli Naive Bayes is : [[1228   29]
#  [ 218  963]]

# %% [markdown]
# Here we can see that among 2438, 2191 were correctly predicted and 247 wrongly predicted.

# %%
print('The Accuracy score of Gaussian Naive Bayes is :',accuracy_score(y_test,y_pred_B))
# Out:
# The Accuracy score of Gaussian Naive Bayes is : 0.898687448728466

# %% [markdown]
# ### <font color='tomato'>III Multinomial Naive Bayes </font><br>
# <br>
#
# __Introduction__<br>
#
# Note that since in multinomial bayes naive there is disadvantage of negative values, so we use the values directly without and scalling on data.<br>

# %%
X1=df1.iloc[:,1:].values
y1=df1.iloc[:,[0]].values

# %%
X1_train,X1_test,y1_train,y1_test=train_test_split(X1,y1,random_state=12,test_size=0.3)

# %%
fit3=MultinomialNB().fit(X1_train,y1_train,)
y_pred_M=fit3.predict(X1_test)
y_pred_M
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
c3=pd.DataFrame(y_test,y_pred_M)
c3.reset_index(inplace=True)
c3.rename(columns={'index':'Actual',0:'Predicted'},inplace=True)
c3.head()
# Out:
#    Actual  Predicted
# 0       0          0
# 1       0          1
# 2       0          1
# 3       1          0
# 4       0          1

# %%
print('The Confusion Matrix of Multinomial Naive Bayes is :',confusion_matrix(y1_test,y_pred_M))
# Out:
# The Confusion Matrix of Multinomial Naive Bayes is : [[1152   93]
#  [ 377  816]]

# %% [markdown]
# Like we saw in the above table,there may have more wrongful predictions occurs when we use the Multinomial Naive Bayes. Using the confusion matrix we can say that out 2438, the correctly predicted is 1968 and wrongly predicted is 470.

# %%
print('The Accuracy score of Multinomial Naive Bayes is :',accuracy_score(y1_test,y_pred_M))
# Out:
# The Accuracy score of Multinomial Naive Bayes is : 0.8072190319934373

# %% [markdown]
# **Conclusion**<br>
# Since the accuracy score for Gaussian NB is greater than other two, we stick with Gaussian NB model.
